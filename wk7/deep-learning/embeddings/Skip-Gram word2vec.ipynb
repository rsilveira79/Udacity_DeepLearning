# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
int_to_vocab
# Out:
# {0: 'the',
#  1: 'of',
#  2: 'and',
#  3: 'one',
#  4: 'in',
#  5: 'a',
#  6: 'to',
#  7: 'zero',
#  8: 'nine',
#  9: 'two',
#  10: 'is',
#  11: 'as',
#  12: 'eight',
#  13: 'for',
#  14: 's',
#  15: 'five',
#  16: 'three',
#  17: 'was',
#  18: 'by',
#  19: 'that',
#  20: 'four',
#  21: 'six',
#  22: 'seven',
#  23: 'with',
#  24: 'on',
#  25: 'are',
#  26: 'it',
#  27: 'from',
#  28: 'or',
#  29: 'his',
#  30: 'an',
#  31: 'be',
#  32: 'this',
#  33: 'which',
#  34: 'at',
#  35: 'he',
#  36: 'also',
#  37: 'not',
#  38: 'have',
#  39: 'were',
#  40: 'has',
#  41: 'but',
#  42: 'other',
#  43: 'their',
#  44: 'its',
#  45: 'first',
#  46: 'they',
#  47: 'some',
#  48: 'had',
#  49: 'all',
#  50: 'more',
#  51: 'most',
#  52: 'can',
#  53: 'been',
#  54: 'such',
#  55: 'many',
#  56: 'who',
#  57: 'new',
#  58: 'used',
#  59: 'there',
#  60: 'after',
#  61: 'when',
#  62: 'into',
#  63: 'american',
#  64: 'time',
#  65: 'these',
#  66: 'only',
#  67: 'see',
#  68: 'may',
#  69: 'than',
#  70: 'world',
#  71: 'i',
#  72: 'b',
#  73: 'would',
#  74: 'd',
#  75: 'no',
#  76: 'however',
#  77: 'between',
#  78: 'about',
#  79: 'over',
#  80: 'years',
#  81: 'states',
#  82: 'people',
#  83: 'war',
#  84: 'during',
#  85: 'united',
#  86: 'known',
#  87: 'if',
#  88: 'called',
#  89: 'use',
#  90: 'th',
#  91: 'system',
#  92: 'often',
#  93: 'state',
#  94: 'so',
#  95: 'history',
#  96: 'will',
#  97: 'up',
#  98: 'while',
#  99: 'where',
#  100: 'city',
#  101: 'being',
#  102: 'english',
#  103: 'then',
#  104: 'any',
#  105: 'both',
#  106: 'under',
#  107: 'out',
#  108: 'made',
#  109: 'well',
#  110: 'her',
#  111: 'e',
#  112: 'number',
#  113: 'government',
#  114: 'them',
#  115: 'm',
#  116: 'later',
#  117: 'since',
#  118: 'him',
#  119: 'part',
#  120: 'name',
#  121: 'c',
#  122: 'century',
#  123: 'through',
#  124: 'because',
#  125: 'x',
#  126: 'university',
#  127: 'early',
#  128: 'life',
#  129: 'british',
#  130: 'year',
#  131: 'like',
#  132: 'same',
#  133: 'including',
#  134: 'became',
#  135: 'example',
#  136: 'day',
#  137: 'each',
#  138: 'even',
#  139: 'work',
#  140: 'language',
#  141: 'although',
#  142: 'several',
#  143: 'form',
#  144: 'john',
#  145: 'u',
#  146: 'national',
#  147: 'very',
#  148: 'much',
#  149: 'g',
#  150: 'french',
#  151: 'before',
#  152: 'general',
#  153: 'what',
#  154: 't',
#  155: 'against',
#  156: 'n',
#  157: 'high',
#  158: 'links',
#  159: 'could',
#  160: 'based',
#  161: 'those',
#  162: 'now',
#  163: 'second',
#  164: 'de',
#  165: 'music',
#  166: 'another',
#  167: 'large',
#  168: 'she',
#  169: 'f',
#  170: 'external',
#  171: 'german',
#  172: 'different',
#  173: 'modern',
#  174: 'great',
#  175: 'do',
#  176: 'common',
#  177: 'set',
#  178: 'list',
#  179: 'south',
#  180: 'series',
#  181: 'major',
#  182: 'game',
#  183: 'power',
#  184: 'long',
#  185: 'country',
#  186: 'king',
#  187: 'law',
#  188: 'group',
#  189: 'film',
#  190: 'still',
#  191: 'until',
#  192: 'north',
#  193: 'international',
#  194: 'term',
#  195: 'we',
#  196: 'end',
#  197: 'book',
#  198: 'found',
#  199: 'own',
#  200: 'political',
#  201: 'party',
#  202: 'order',
#  203: 'usually',
#  204: 'president',
#  205: 'church',
#  206: 'you',
#  207: 'death',
#  208: 'theory',
#  209: 'area',
#  210: 'around',
#  211: 'include',
#  212: 'god',
#  213: 'ii',
#  214: 'way',
#  215: 'did',
#  216: 'military',
#  217: 'population',
#  218: 'using',
#  219: 'though',
#  220: 'small',
#  221: 'following',
#  222: 'within',
#  223: 'non',
#  224: 'human',
#  225: 'left',
#  226: 'main',
#  227: 'among',
#  228: 'point',
#  229: 'r',
#  230: 'due',
#  231: 'p',
#  232: 'considered',
#  233: 'public',
#  234: 'popular',
#  235: 'computer',
#  236: 'west',
#  237: 'family',
#  238: 'east',
#  239: 'information',
#  240: 'important',
#  241: 'european',
#  242: 'man',
#  243: 'sometimes',
#  244: 'right',
#  245: 'old',
#  246: 'free',
#  247: 'word',
#  248: 'without',
#  249: 'last',
#  250: 'us',
#  251: 'members',
#  252: 'given',
#  253: 'times',
#  254: 'roman',
#  255: 'make',
#  256: 'h',
#  257: 'age',
#  258: 'place',
#  259: 'l',
#  260: 'thus',
#  261: 'science',
#  262: 'case',
#  263: 'become',
#  264: 'systems',
#  265: 'union',
#  266: 'born',
#  267: 'york',
#  268: 'line',
#  269: 'countries',
#  270: 'does',
#  271: 'isbn',
#  272: 'st',
#  273: 'control',
#  274: 'various',
#  275: 'others',
#  276: 'house',
#  277: 'article',
#  278: 'island',
#  279: 'should',
#  280: 'led',
#  281: 'back',
#  282: 'period',
#  283: 'player',
#  284: 'europe',
#  285: 'languages',
#  286: 'central',
#  287: 'water',
#  288: 'few',
#  289: 'western',
#  290: 'home',
#  291: 'began',
#  292: 'generally',
#  293: 'less',
#  294: 'k',
#  295: 'similar',
#  296: 'written',
#  297: 'original',
#  298: 'best',
#  299: 'must',
#  300: 'according',
#  301: 'school',
#  302: 'france',
#  303: 'air',
#  304: 'single',
#  305: 'force',
#  306: 'v',
#  307: 'land',
#  308: 'groups',
#  309: 'down',
#  310: 'how',
#  311: 'works',
#  312: 'development',
#  313: 'official',
#  314: 'support',
#  315: 'england',
#  316: 'j',
#  317: 'rather',
#  318: 'data',
#  319: 'space',
#  320: 'greek',
#  321: 'km',
#  322: 'named',
#  323: 'germany',
#  324: 'just',
#  325: 'games',
#  326: 'said',
#  327: 'version',
#  328: 'late',
#  329: 'earth',
#  330: 'company',
#  331: 'every',
#  332: 'economic',
#  333: 'short',
#  334: 'published',
#  335: 'black',
#  336: 'army',
#  337: 'off',
#  338: 'london',
#  339: 'million',
#  340: 'body',
#  341: 'field',
#  342: 'christian',
#  343: 'either',
#  344: 'empire',
#  345: 'social',
#  346: 'o',
#  347: 'developed',
#  348: 'standard',
#  349: 'court',
#  350: 'service',
#  351: 'kingdom',
#  352: 'along',
#  353: 'college',
#  354: 'republic',
#  355: 'sea',
#  356: 'america',
#  357: 'today',
#  358: 'result',
#  359: 'held',
#  360: 'team',
#  361: 'light',
#  362: 'means',
#  363: 'never',
#  364: 'especially',
#  365: 'third',
#  366: 'further',
#  367: 'forces',
#  368: 'character',
#  369: 'take',
#  370: 'men',
#  371: 'society',
#  372: 'show',
#  373: 'open',
#  374: 'possible',
#  375: 'fact',
#  376: 'battle',
#  377: 'took',
#  378: 'former',
#  379: 'books',
#  380: 'soviet',
#  381: 'river',
#  382: 'children',
#  383: 'having',
#  384: 'good',
#  385: 'local',
#  386: 'current',
#  387: 'son',
#  388: 'process',
#  389: 'natural',
#  390: 'present',
#  391: 'himself',
#  392: 'islands',
#  393: 'total',
#  394: 'near',
#  395: 'white',
#  396: 'days',
#  397: 'person',
#  398: 'itself',
#  399: 'seen',
#  400: 'culture',
#  401: 'little',
#  402: 'above',
#  403: 'software',
#  404: 'largest',
#  405: 'words',
#  406: 'upon',
#  407: 'level',
#  408: 'father',
#  409: 'created',
#  410: 'side',
#  411: 'red',
#  412: 'references',
#  413: 'press',
#  414: 'full',
#  415: 'region',
#  416: 'almost',
#  417: 'al',
#  418: 'image',
#  419: 'famous',
#  420: 'play',
#  421: 'came',
#  422: 'role',
#  423: 'once',
#  424: 'certain',
#  425: 'league',
#  426: 'jewish',
#  427: 'james',
#  428: 'january',
#  429: 'site',
#  430: 'again',
#  431: 'art',
#  432: 'numbers',
#  433: 'member',
#  434: 'areas',
#  435: 'movement',
#  436: 'religious',
#  437: 'type',
#  438: 'march',
#  439: 'community',
#  440: 'story',
#  441: 'played',
#  442: 'production',
#  443: 'released',
#  444: 'center',
#  445: 'rights',
#  446: 'real',
#  447: 'related',
#  448: 'foreign',
#  449: 'low',
#  450: 'ancient',
#  451: 'view',
#  452: 'terms',
#  453: 'source',
#  454: 'act',
#  455: 'minister',
#  456: 'change',
#  457: 'energy',
#  458: 'produced',
#  459: 'research',
#  460: 'actor',
#  461: 'making',
#  462: 'civil',
#  463: 'december',
#  464: 'women',
#  465: 'special',
#  466: 'style',
#  467: 'design',
#  468: 'japanese',
#  469: 'william',
#  470: 'available',
#  471: 'chinese',
#  472: 'forms',
#  473: 'canada',
#  474: 'northern',
#  475: 'died',
#  476: 'class',
#  477: 'living',
#  478: 'next',
#  479: 'particular',
#  480: 'program',
#  481: 'council',
#  482: 'television',
#  483: 'head',
#  484: 'david',
#  485: 'china',
#  486: 'middle',
#  487: 'established',
#  488: 'bc',
#  489: 'hand',
#  490: 'far',
#  491: 'july',
#  492: 'function',
#  493: 'position',
#  494: 'y',
#  495: 'built',
#  496: 'george',
#  497: 'band',
#  498: 'together',
#  499: 'w',
#  500: 'latin',
#  501: 'thought',
#  502: 'eastern',
#  503: 'charles',
#  504: 'parts',
#  505: 'instead',
#  506: 'study',
#  507: 'india',
#  508: 'might',
#  509: 'code',
#  510: 'included',
#  511: 'meaning',
#  512: 'trade',
#  513: 'per',
#  514: 'june',
#  515: 'least',
#  516: 'half',
#  517: 'model',
#  518: 'economy',
#  519: 'prime',
#  520: 'traditional',
#  521: 'always',
#  522: 'capital',
#  523: 'range',
#  524: 'emperor',
#  525: 'november',
#  526: 'young',
#  527: 'anti',
#  528: 'final',
#  529: 'text',
#  530: 'players',
#  531: 'uk',
#  532: 'april',
#  533: 'run',
#  534: 'september',
#  535: 'addition',
#  536: 'radio',
#  537: 'live',
#  538: 'august',
#  539: 'taken',
#  540: 'note',
#  541: 'italian',
#  542: 'lost',
#  543: 'nature',
#  544: 'project',
#  545: 'technology',
#  546: 'spanish',
#  547: 'october',
#  548: 'recent',
#  549: 'rate',
#  550: 'won',
#  551: 'true',
#  552: 'value',
#  553: 'uses',
#  554: 'russian',
#  555: 'est',
#  556: 'wrote',
#  557: 'effect',
#  558: 'album',
#  559: 'southern',
#  560: 'africa',
#  561: 'whose',
#  562: 'top',
#  563: 'historical',
#  564: 'australia',
#  565: 'catholic',
#  566: 'particularly',
#  567: 'self',
#  568: 'structure',
#  569: 'record',
#  570: 'evidence',
#  571: 'themselves',
#  572: 'rule',
#  573: 'influence',
#  574: 'cases',
#  575: 'subject',
#  576: 'referred',
#  577: 'continued',
#  578: 'nations',
#  579: 'rock',
#  580: 'below',
#  581: 'japan',
#  582: 'com',
#  583: 'song',
#  584: 'throughout',
#  585: 'names',
#  586: 'female',
#  587: 'title',
#  588: 'therefore',
#  589: 'our',
#  590: 'office',
#  591: 'star',
#  592: 'paul',
#  593: 'too',
#  594: 'cities',
#  595: 'february',
#  596: 'independent',
#  597: 'author',
#  598: 'problem',
#  599: 'species',
#  600: 'education',
#  601: 'done',
#  602: 'philosophy',
#  603: 'come',
#  604: 'higher',
#  605: 'originally',
#  606: 'market',
#  607: 'town',
#  608: 'my',
#  609: 'season',
#  610: 'love',
#  611: 'strong',
#  612: 'israel',
#  613: 'writer',
#  614: 'irish',
#  615: 'films',
#  616: 'elements',
#  617: 'robert',
#  618: 'whether',
#  619: 'despite',
#  620: 'eventually',
#  621: 'here',
#  622: 'football',
#  623: 'action',
#  624: 'internet',
#  625: 'individual',
#  626: 'sound',
#  627: 'network',
#  628: 'described',
#  629: 'practice',
#  630: 'characters',
#  631: 're',
#  632: 'royal',
#  633: 'la',
#  634: 'events',
#  635: 'formed',
#  636: 'commonly',
#  637: 'base',
#  638: 'received',
#  639: 'african',
#  640: 'problems',
#  641: 'food',
#  642: 'jews',
#  643: 'able',
#  644: 'male',
#  645: 'typically',
#  646: 'mass',
#  647: 'complex',
#  648: 'lower',
#  649: 'includes',
#  650: 'outside',
#  651: 'legal',
#  652: 'complete',
#  653: 'parliament',
#  654: 'significant',
#  655: 'actually',
#  656: 'business',
#  657: 'fiction',
#  658: 'physical',
#  659: 'followed',
#  660: 'deaths',
#  661: 'key',
#  662: 'leader',
#  663: 'widely',
#  664: 'page',
#  665: 'basic',
#  666: 'types',
#  667: 'henry',
#  668: 'elected',
#  669: 'beginning',
#  670: 'fire',
#  671: 'building',
#  672: 'independence',
#  673: 'went',
#  674: 'movie',
#  675: 'aircraft',
#  676: 'ever',
#  677: 'canadian',
#  678: 'material',
#  679: 'births',
#  680: 'video',
#  681: 'news',
#  682: 'future',
#  683: 'scientific',
#  684: 'simply',
#  685: 'go',
#  686: 'defined',
#  687: 'laws',
#  688: 'get',
#  689: 'close',
#  690: 'industry',
#  691: 'specific',
#  692: 'examples',
#  693: 'believe',
#  694: 'services',
#  695: 'idea',
#  696: 'introduced',
#  697: 'method',
#  698: 'points',
#  699: 'return',
#  700: 'cause',
#  701: 'indian',
#  702: 'britain',
#  703: 'features',
#  704: 'size',
#  705: 'majority',
#  706: 'post',
#  707: 'lead',
#  708: 'organization',
#  709: 'cannot',
#  710: 'designed',
#  711: 'ireland',
#  712: 'cross',
#  713: 'classical',
#  714: 'personal',
#  715: 'writing',
#  716: 'concept',
#  717: 'required',
#  718: 'associated',
#  719: 'soon',
#  720: 'changes',
#  721: 'california',
#  722: 'located',
#  723: 'sense',
#  724: 'believed',
#  725: 'away',
#  726: 'started',
#  727: 'co',
#  728: 'religion',
#  729: 'mother',
#  730: 'county',
#  731: 'rules',
#  732: 'studies',
#  733: 'yet',
#  734: 'find',
#  735: 'knowledge',
#  736: 'put',
#  737: 'founded',
#  738: 'policy',
#  739: 'currently',
#  740: 'provide',
#  741: 'working',
#  742: 'media',
#  743: 'election',
#  744: 'australian',
#  745: 'me',
#  746: 'thomas',
#  747: 'allowed',
#  748: 'russia',
#  749: 'earlier',
#  750: 'greater',
#  751: 'limited',
#  752: 'object',
#  753: 'brought',
#  754: 'online',
#  755: 'lord',
#  756: 'association',
#  757: 'mostly',
#  758: 'blue',
#  759: 'constitution',
#  760: 'across',
#  761: 'added',
#  762: 'interest',
#  763: 'things',
#  764: 'relations',
#  765: 'speed',
#  766: 'federal',
#  767: 'singer',
#  768: 'effects',
#  769: 'growth',
#  770: 'sources',
#  771: 'your',
#  772: 'remains',
#  773: 'z',
#  774: 'probably',
#  775: 'gave',
#  776: 'simple',
#  777: 'attack',
#  778: 'longer',
#  779: 'reference',
#  780: 'saint',
#  781: 'success',
#  782: 'killed',
#  783: 'career',
#  784: 'past',
#  785: 'need',
#  786: 'park',
#  787: 'definition',
#  788: 'say',
#  789: 'etc',
#  790: 'give',
#  791: 'peace',
#  792: 'chief',
#  793: 'stories',
#  794: 'security',
#  795: 'wide',
#  796: 'ball',
#  797: 'saw',
#  798: 'machine',
#  799: 'better',
#  800: 'cell',
#  801: 'leading',
#  802: 'becomes',
#  803: 'spain',
#  804: 'larger',
#  805: 'products',
#  806: 'night',
#  807: 'parties',
#  808: 'remained',
#  809: 'prize',
#  810: 'months',
#  811: 'website',
#  812: 'big',
#  813: 'money',
#  814: 'cultural',
#  815: 'territory',
#  816: 'help',
#  817: 'moved',
#  818: 'private',
#  819: 'wife',
#  820: 'letter',
#  821: 'politics',
#  822: 'lines',
#  823: 'largely',
#  824: 'contains',
#  825: 'companies',
#  826: 'lake',
#  827: 'perhaps',
#  828: 'green',
#  829: 'already',
#  830: 'iii',
#  831: 'dead',
#  832: 'library',
#  833: 'separate',
#  834: 'refer',
#  835: 'makes',
#  836: 'appeared',
#  837: 'dutch',
#  838: 'holy',
#  839: 'era',
#  840: 'novel',
#  841: 'successful',
#  842: 'italy',
#  843: 'letters',
#  844: 'results',
#  845: 'matter',
#  846: 'produce',
#  847: 'origin',
#  848: 'claim',
#  849: 'whole',
#  850: 'directly',
#  851: 'attempt',
#  852: 'actress',
#  853: 'surface',
#  854: 'revolution',
#  855: 'highly',
#  856: 'caused',
#  857: 'status',
#  858: 'musical',
#  859: 'richard',
#  860: 'commercial',
#  861: 'division',
#  862: 'color',
#  863: 'release',
#  864: 'health',
#  865: 'coast',
#  866: 'latter',
#  867: 'authority',
#  868: 'treaty',
#  869: 'turn',
#  870: 'michael',
#  871: 'nation',
#  872: 'direct',
#  873: 'asia',
#  874: 'edition',
#  875: 'programming',
#  876: 'playing',
#  877: 'date',
#  878: 'native',
#  879: 'mary',
#  880: 'whom',
#  881: 'married',
#  882: 'towards',
#  883: 'issues',
#  884: 'double',
#  885: 'primary',
#  886: 'basis',
#  887: 'enough',
#  888: 'allow',
#  889: 'memory',
#  890: 'reason',
#  891: 'web',
#  892: 'exist',
#  893: 'provided',
#  894: 'functions',
#  895: 'oil',
#  896: 'course',
#  897: 'chemical',
#  898: 'analysis',
#  899: 'alexander',
#  900: 'mid',
#  901: 'replaced',
#  902: 'queen',
#  903: 'sun',
#  904: 'claims',
#  905: 'tv',
#  906: 'literature',
#  907: 'metal',
#  908: 'amount',
#  909: 'divided',
#  910: 'blood',
#  911: 'likely',
#  912: 'average',
#  913: 'access',
#  914: 'length',
#  915: 'smaller',
#  916: 'medical',
#  917: 'property',
#  918: 'students',
#  919: 'degree',
#  920: 'elections',
#  921: 'club',
#  922: 'claimed',
#  923: 'performance',
#  924: 'director',
#  925: 'digital',
#  926: 'front',
#  927: 'museum',
#  928: 'difficult',
#  929: 'tradition',
#  930: 'nearly',
#  931: 'schools',
#  932: 'washington',
#  933: 'gas',
#  934: 'map',
#  935: 'jesus',
#  936: 'louis',
#  937: 'rome',
#  938: 'unit',
#  939: 'baseball',
#  940: 'mind',
#  941: 'mark',
#  942: 'peter',
#  943: 'collection',
#  944: 'product',
#  945: 'congress',
#  946: 'programs',
#  947: 'changed',
#  948: 'ideas',
#  949: 'moon',
#  950: 'entire',
#  951: 'user',
#  952: 'ground',
#  953: 'records',
#  954: 'frequently',
#  955: 'increase',
#  956: 'highest',
#  957: 'sent',
#  958: 'finally',
#  959: 'board',
#  960: 'don',
#  961: 'notable',
#  962: 'read',
#  963: 'methods',
#  964: 'recently',
#  965: 'bit',
#  966: 'variety',
#  967: 'involved',
#  968: 'call',
#  969: 'democratic',
#  970: 'ten',
#  971: 'served',
#  972: 'minor',
#  973: 'hard',
#  974: 'objects',
#  975: 'birth',
#  976: 'increased',
#  977: 'nuclear',
#  978: 'section',
#  979: 'street',
#  980: 'windows',
#  981: 'relatively',
#  982: 'car',
#  983: 'move',
#  984: 'create',
#  985: 'returned',
#  986: 'bank',
#  987: 'conditions',
#  988: 'operation',
#  989: 'adopted',
#  990: 'relationship',
#  991: 'christ',
#  992: 'hall',
#  993: 'appear',
#  994: 'rest',
#  995: 'child',
#  996: 'element',
#  997: 'appears',
#  998: 'fall',
#  999: 'takes',
#  ...}

# %%
int_words
# Out:
# [5243,
#  3081,
#  11,
#  5,
#  194,
#  1,
#  3136,
#  45,
#  58,
#  155,
#  127,
#  741,
#  476,
#  10602,
#  133,
#  0,
#  27812,
#  1,
#  0,
#  102,
#  854,
#  2,
#  0,
#  15124,
#  62330,
#  1,
#  0,
#  150,
#  854,
#  3582,
#  0,
#  194,
#  10,
#  190,
#  58,
#  4,
#  5,
#  10758,
#  214,
#  6,
#  1324,
#  104,
#  454,
#  19,
#  58,
#  2731,
#  362,
#  6,
#  3674,
#  0,
#  708,
#  1,
#  371,
#  26,
#  40,
#  36,
#  53,
#  539,
#  97,
#  11,
#  5,
#  1424,
#  2757,
#  18,
#  567,
#  686,
#  7098,
#  0,
#  247,
#  5243,
#  10,
#  1052,
#  27,
#  0,
#  320,
#  248,
#  46348,
#  2878,
#  792,
#  186,
#  5243,
#  11,
#  5,
#  200,
#  602,
#  10,
#  0,
#  1135,
#  19,
#  2622,
#  25,
#  9010,
#  2,
#  279,
#  31,
#  4153,
#  141,
#  59,
#  25,
#  6438,
#  4189,
#  1,
#  153,
#  32,
#  362,
#  5243,
#  36,
#  1137,
#  6,
#  447,
#  345,
#  1818,
#  19,
#  4871,
#  0,
#  6769,
#  1,
#  7585,
#  1774,
#  566,
#  0,
#  93,
#  0,
#  247,
#  11142,
#  11,
#  51,
#  7098,
#  89,
#  26,
#  270,
#  37,
#  5951,
#  4873,
#  20472,
#  28,
#  55154,
#  41,
#  317,
#  5,
#  25681,
#  527,
#  7585,
#  371,
#  4,
#  258,
#  1,
#  153,
#  25,
#  1206,
#  11,
#  7585,
#  200,
#  1578,
#  2,
#  15218,
#  332,
#  1774,
#  7098,
#  4871,
#  345,
#  764,
#  160,
#  406,
#  5710,
#  756,
#  1,
#  4116,
#  1131,
#  4340,
#  1536,
#  2,
#  567,
#  8129,
#  98,
#  5243,
#  10,
#  51,
#  1407,
#  686,
#  18,
#  153,
#  26,
#  10,
#  155,
#  7098,
#  36,
#  2035,
#  1424,
#  8177,
#  1,
#  153,
#  46,
#  693,
#  6,
#  31,
#  5,
#  4154,
#  246,
#  371,
#  76,
#  948,
#  78,
#  310,
#  30,
#  4784,
#  371,
#  508,
#  139,
#  2313,
#  3557,
#  364,
#  23,
#  1823,
#  6,
#  1902,
#  59,
#  10,
#  36,
#  8424,
#  78,
#  310,
#  5,
#  246,
#  371,
#  508,
#  31,
#  753,
#  78,
#  1732,
#  2,
#  8079,
#  24327,
#  2,
#  275,
#  1693,
#  19,
#  151,
#  1034,
#  95,
#  224,
#  371,
#  17,
#  1817,
#  24,
#  4784,
#  1556,
#  51,
#  8120,
#  1465,
#  24327,
#  2,
#  12747,
#  4,
#  6130,
#  19,
#  4187,
#  21351,
#  2427,
#  39,
#  16477,
#  2,
#  7250,
#  861,
#  1,
#  1193,
#  10251,
#  2514,
#  28,
#  15176,
#  187,
#  2,
#  48,
#  1123,
#  913,
#  6,
#  1049,
#  469,
#  12315,
#  7098,
#  133,
#  0,
#  0,
#  11142,
#  3061,
#  2,
#  12073,
#  734,
#  4784,
#  6614,
#  4,
#  14665,
#  27,
#  450,
#  485,
#  24327,
#  198,
#  295,
#  948,
#  4,
#  20045,
#  20393,
#  1,
#  54072,
#  300,
#  6,
#  24327,
#  20393,
#  16629,
#  0,
#  30413,
#  1,
#  0,
#  93,
#  44,
#  3832,
#  2,
#  54637,
#  2,
#  3807,
#  0,
#  3412,
#  1,
#  0,
#  1781,
#  187,
#  1,
#  0,
#  625,
#  0,
#  13242,
#  1,
#  3,
#  21,
#  90,
#  122,
#  284,
#  25,
#  243,
#  232,
#  6,
#  31,
#  436,
#  26365,
#  1,
#  173,
#  5243,
#  7705,
#  2535,
#  4,
#  29,
#  95,
#  1,
#  289,
#  602,
#  4310,
#  19,
#  0,
#  13242,
#  16629,
#  49,
#  187,
#  117,
#  46,
#  359,
#  19,
#  0,
#  384,
#  242,
#  96,
#  31,
#  5241,
#  34,
#  331,
#  2727,
#  18,
#  0,
#  838,
#  1378,
#  27,
#  32,
#  8793,
#  46,
#  6477,
#  34,
#  3246,
#  0,
#  27812,
#  28,
#  551,
#  43979,
#  39,
#  30,
#  127,
#  55444,
#  435,
#  84,
#  0,
#  64,
#  1,
#  0,
#  102,
#  462,
#  83,
#  2,
#  25,
#  232,
#  18,
#  47,
#  11,
#  26365,
#  1,
#  173,
#  5243,
#  4,
#  0,
#  173,
#  839,
#  0,
#  45,
#  6,
#  89,
#  0,
#  194,
#  6,
#  1015,
#  1043,
#  42,
#  69,
#  4873,
#  17,
#  936,
#  14931,
#  4578,
#  164,
#  4,
#  29,
#  41127,
#  11830,
#  23191,
#  259,
#  1225,
#  58859,
#  3,
#  22,
#  7,
#  16,
#  99,
#  35,
#  628,
#  0,
#  2664,
#  63,
#  371,
#  33,
#  48,
#  75,
#  93,
#  687,
#  14782,
#  4052,
#  28,
#  818,
#  917,
#  11,
#  101,
#  4,
#  11142,
#  2535,
#  362,
#  5,
#  6055,
#  2,
#  662,
#  4,
#  0,
#  63,
#  701,
#  435,
#  40,
#  4224,
#  1290,
#  19,
#  35,
#  10,
#  30,
#  4784,
#  2,
#  94,
#  25,
#  49,
#  29,
#  5222,
#  4,
#  3,
#  22,
#  8,
#  16,
#  4,
#  0,
#  5359,
#  1,
#  0,
#  150,
#  854,
#  469,
#  12315,
#  334,
#  30,
#  17246,
#  2434,
#  200,
#  1293,
#  141,
#  12315,
#  215,
#  37,
#  89,
#  0,
#  247,
#  5243,
#  55,
#  116,
#  7098,
#  38,
#  1206,
#  32,
#  197,
#  11,
#  0,
#  45,
#  181,
#  4784,
#  529,
#  2,
#  12315,
#  11,
#  0,
#  1834,
#  1,
#  1913,
#  5243,
#  41,
#  34,
#  32,
#  228,
#  75,
#  4784,
#  435,
#  733,
#  2403,
#  2,
#  0,
#  194,
#  17,
#  86,
#  1073,
#  11,
#  30,
#  14112,
#  30597,
#  18,
#  0,
#  12067,
#  58831,
#  34,
#  50,
#  2421,
#  616,
#  4,
#  0,
#  150,
#  854,
#  0,
#  45,
#  567,
#  8737,
#  4784,
#  2935,
#  1032,
#  14590,
#  26,
#  10,
#  636,
#  359,
#  19,
#  26,
#  5400,
#  154,
#  191,
#  2935,
#  1032,
#  14590,
#  334,
#  153,
#  10,
#  917,
#  4,
#  3,
#  12,
#  20,
#  7,
#  19,
#  0,
#  194,
#  4784,
#  17,
#  989,
#  11,
#  5,
#  567,
#  1608,
#  26,
#  10,
#  13,
#  32,
#  890,
#  19,
#  47,
#  848,
#  14590,
#  11,
#  0,
#  1834,
#  1,
#  173,
#  4784,
#  208,
#  4,
#  153,
#  10,
#  917,
#  14590,
#  5469,
#  23,
#  0,
#  419,
#  12953,
#  917,
#  10,
#  6891,
#  4,
#  32,
#  139,
#  35,
#  1346,
#  0,
#  2877,
#  1,
#  15176,
#  917,
#  154,
#  99,
#  3470,
#  38,
#  652,
#  445,
#  6,
#  89,
#  2,
#  3136,
#  43,
#  917,
#  11,
#  46,
#  3596,
#  54,
#  11,
#  15374,
#  1555,
#  13,
#  2967,
#  4,
#  44,
#  258,
#  14590,
#  1165,
#  153,
#  35,
#  88,
#  3223,
#  1131,
#  52,
#  38,
#  751,
#  445,
#  6,
#  89,
#  1049,
#  522,
#  2,
#  1793,
#  4,
#  5819,
#  23,
#  1556,
#  1,
#  5133,
#  2,
#  1293,
#  14590,
#  14,
#  2655,
#  1,
#  11142,
#  33,
#  35,
#  88,
#  29466,
#  967,
#  30,
#  1334,
#  518,
#  99,
#  1131,
#  2,
#  308,
#  159,
#  512,
#  0,
#  805,
#  1,
#  43,
#  1258,
#  218,
#  1258,
#  1037,
#  33,
#  1391,
#  0,
#  908,
#  1,
#  741,
#  64,
#  967,
#  4,
#  442,
#  32,
#  73,
#  2917,
#  19,
#  75,
#  3,
#  73,
#  2967,
#  27,
#  0,
#  1258,
#  1,
#  275,
#  1555,
#  159,
#  4327,
#  2520,
#  498,
#  4,
#  727,
#  10655,
#  18879,
#  30,
#  762,
#  246,
#  986,
#  73,
#  31,
#  177,
#  97,
#  6,
#  740,
#  3272,
#  23,
#  913,
#  6,
#  0,
#  362,
#  1,
#  442,
#  14590,
#  14,
#  948,
#  39,
#  2025,
#  222,
#  150,
#  741,
#  476,
#  1818,
#  2,
#  29,
#  2986,
#  39,
#  1022,
#  4,
#  0,
#  854,
#  1,
#  3,
#  12,
#  20,
#  12,
#  4,
#  302,
#  14590,
#  14,
#  602,
#  1,
#  917,
#  10,
#  647,
#  26,
#  17,
#  347,
#  4,
#  5,
#  112,
#  1,
#  311,
#  79,
#  29,
#  3571,
#  2,
#  59,
#  25,
#  6438,
#  4189,
#  1,
#  47,
#  1,
#  29,
#  948,
#  13,
#  50,
#  2158,
#  1590,
#  67,
#  621,
#  2753,
#  26600,
#  14,
#  15664,
#  4,
#  29,
#  0,
#  10509,
#  2,
#  44,
#  199,
#  26600,
#  1461,
#  19,
#  51,
#  636,
#  1046,
#  345,
#  1774,
#  133,
#  0,
#  2583,
#  1,
#  93,
#  917,
#  11,
#  5,
#  244,
#  389,
#  445,
#  4,
#  152,
#  2,
#  0,
#  147,
#  2583,
#  1,
#  371,
#  39,
#  4588,
#  20854,
#  28,
#  9257,
#  4,
#  0,
#  940,
#  1976,
#  1,
#  371,
#  19,
#  0,
#  1131,
#  25,
#  44,
#  1729,
#  35,
#  5227,
#  15664,
#  2,
#  5,
#  143,
#  1,
#  4,
#  33,
#  1131,
#  73,
#  9768,
#  4,
#  5835,
#  1,
#  51679,
#  66,
#  61,
#  26,
#  17,
#  4,
#  43,
#  567,
#  762,
#  6,
#  175,
#  94,
#  13,
#  118,
#  917,
#  684,
#  1146,
#  78,
#  123,
#  508,
#  13140,
#  5572,
#  310,
#  6,
#  369,
#  6,
#  4115,
#  0,
#  1797,
#  6,
#  118,
#  5475,
#  917,
#  2,
#  153,
#  71,
#  38,
#  4,
#  608,
#  183,
#  19,
#  10,
#  608,
#  199,
#  94,
#  184,
#  11,
#  71,
#  6200,
#  9077,
#  11,
#  7183,
#  71,
#  1225,
#  0,
#  34154,
#  1,
#  0,
#  1797,
#  26600,
#  363,
#  88,
#  391,
#  30,
#  4784,
#  35,
#  1046,
#  66,
#  0,
#  2757,
#  43878,
#  2068,
#  29,
#  948,
#  39,
#  2025,
#  24,
#  55,
#  9930,
#  7098,
#  141,
#  4189,
#  1,
#  29,
#  501,
#  25,
#  3235,
#  63,
#  10327,
#  5243,
#  3244,
#  9629,
#  4,
#  3,
#  ...]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
print(int_words[:10])
# Out:
# [5243, 3081, 11, 5, 194, 1, 3136, 45, 58, 155]

# %%
def subsampling(word, thresh):
    prob=np.maximum(0,1-np.sqrt((thresh)/np.asarray(word)))

# %%
print(subsampling(int_words[:10],50))
# Out:
# None

# %%
## Your code here
thresh=0.5
train_words = 1-np.sqrt((thresh)/np.asarray(int_words))
# Out:
# d:\Anaconda3\envs\tflearn\lib\site-packages\ipykernel\__main__.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   app.launch_new_instance()

# %%
len(int_words)
# Out:
# 16680599

# %%
len(train_words)
# Out:
# 16680599

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if p_drop[word] < random.random()]

# %%
print("Size of train words {} vs size of total words {}".format(len(train_words),len(int_words)))
# Out:
# Size of train words 4629167 vs size of total words 16680599

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(dtype=tf.int32, shape=None, name ='inputs')
    labels = tf.placeholder(dtype=tf.int32, shape=[None,None], name = 'labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6305 0.2572 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6391 0.2450 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4992 0.2199 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5842 0.2245 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5055 0.1942 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5286 0.2032 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5634 0.3083 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5602 0.2783 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4864 0.2938 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4452 0.2743 sec/batch
# Nearest to and: in, quay, diversification, hauser, introduced, surgeries, veal, tyrannical,
# Nearest to nine: redefining, cables, pub, aalborg, conjuring, keitai, brimstone, christianized,
# Nearest to all: subdivision, subnet, horsemanship, kilgore, carl, borate, footsteps, auction,
# Nearest to has: sunk, kops, conspiratorial, pakistani, discipline, angelika, side, dedham,
# Nearest to is: torpedo, unphysical, accumulation, luftwaffe, berries, nolan, nadu, presses,
# Nearest to it: discredited, timings, scribner, carnivorous, speculators, psychopathology, projecting, broch,
# Nearest to seven: sees, com, foes, py, excursions, theirs, brothels, defied,
# Nearest to as: ugosz, congolese, terminally, oscillator, critica, linguist, rather, cancellous,
# Nearest to institute: lipinski, contessa, confidentially, altdorfer, conjugations, leaky, gigantopithecus, superposition,
# Nearest to issue: ayahuasca, larger, diminish, agent, angering, immaterial, clk, south,
# Nearest to operating: flair, surfing, telemann, wounding, caledonia, timescales, halakhic, reb,
# Nearest to active: oto, seventy, antipsychotic, trinomial, moe, mccartney, romantically, tekoa,
# Nearest to http: oaks, novas, registrar, auspices, semester, crone, dosadi, sanl,
# Nearest to creation: yeltsin, ra, orphic, pomerania, ruse, emilio, boltzmann, lithographica,
# Nearest to engineering: dvg, gallop, responding, broadcasting, snapshot, earthquake, curious, stretchy,
# Nearest to additional: tomita, inte, epona, elite, overstepped, philologist, toy, bowels,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4796 0.2721 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3989 0.2116 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3165 0.2795 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2362 0.2916 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1588 0.2879 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1504 0.2804 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1009 0.2793 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0484 0.2783 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0070 0.2803 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9806 0.3013 sec/batch
# Nearest to and: in, reading, quay, diversification, introduced, tyrannical, hauser, veal,
# Nearest to nine: pub, redefining, cables, aalborg, season, conjuring, brimstone, christianized,
# Nearest to all: subdivision, subnet, carl, imagine, auction, kilgore, horsemanship, itself,
# Nearest to has: discipline, sunk, side, pakistani, geographically, intensity, indirectly, kops,
# Nearest to is: accumulation, torpedo, completely, presses, luftwaffe, unphysical, byte, nadu,
# Nearest to it: discredited, less, past, each, scribner, timings, carnivorous, advantage,
# Nearest to seven: sees, com, foes, day, theirs, jewelry, py, brothels,
# Nearest to as: rather, congolese, linguist, oscillator, agree, with, prohibits, combined,
# Nearest to institute: lipinski, contessa, altdorfer, dover, jul, confidentially, booked, superposition,
# Nearest to issue: larger, south, tsunamis, agent, ayahuasca, halls, reagents, convenience,
# Nearest to operating: af, surfing, dramatic, words, wounding, caledonia, halakhic, network,
# Nearest to active: seventy, oto, rest, converse, unfortunately, occured, antipsychotic, formalist,
# Nearest to http: oaks, registrar, semester, novas, revisions, seneca, moderation, auspices,
# Nearest to creation: ra, pomerania, yeltsin, planting, producers, denunciation, strenuously, orphic,
# Nearest to engineering: responding, broadcasting, dvg, gallop, snapshot, curious, earthquake, abolished,
# Nearest to additional: tomita, standard, earlier, inte, toy, reproduce, elite, overstepped,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9204 0.2595 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8883 0.2884 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8947 0.2899 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8833 0.3492 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8182 0.3155 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8238 0.2994 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8219 0.3131 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7899 0.2279 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7949 0.2544 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7774 0.2693 sec/batch
# Nearest to and: in, conquer, reading, quay, protects, diversification, hauser, nazi,
# Nearest to nine: redefining, pub, cables, jesuit, christianized, one, inventors, w,
# Nearest to all: subdivision, horsemanship, subnet, auction, ethyl, imagine, gradus, carl,
# Nearest to has: sunk, discipline, pakistani, side, geographically, kops, ieee, reorganized,
# Nearest to is: accumulation, berries, torpedo, byte, completely, unphysical, luftwaffe, modula,
# Nearest to it: discredited, less, past, scribner, timings, each, speculators, psychopathology,
# Nearest to seven: foes, com, theirs, sees, one, day, ka, saint,
# Nearest to as: rather, linguist, oscillator, congolese, prohibits, agree, terminally, novels,
# Nearest to institute: lipinski, jul, contessa, altdorfer, dover, booked, ban, confidentially,
# Nearest to issue: larger, agent, tsunamis, reagents, south, ayahuasca, convenience, diminish,
# Nearest to operating: professors, dramatic, surfing, af, wounding, spokesman, satellites, telemann,
# Nearest to active: seventy, oto, diagonal, occured, mccartney, antipsychotic, formalist, unfortunately,
# Nearest to http: registrar, oaks, revisions, semester, auspices, remarkable, seneca, novas,
# Nearest to creation: pomerania, ra, producers, orphic, denunciation, yeltsin, planting, wage,
# Nearest to engineering: responding, snapshot, gallop, dvg, curious, earthquake, broadcasting, color,
# Nearest to additional: elite, toy, tomita, reproduce, standard, inte, overstepped, earlier,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7675 0.2990 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7580 0.3656 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7169 0.3026 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6965 0.3248 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7728 0.3014 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7183 0.3094 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7112 0.3031 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7326 0.3030 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6903 0.2971 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6343 0.2983 sec/batch
# Nearest to and: in, conquer, reading, diversification, protects, elector, hauser, surgeries,
# Nearest to nine: six, one, jesuit, w, inventors, medici, musician, redefining,
# Nearest to all: subdivision, ethyl, horsemanship, subnet, auction, footsteps, pilgrims, warn,
# Nearest to has: sunk, discipline, pakistani, side, angelika, kops, ieee, geographically,
# Nearest to is: berries, byte, accumulation, unphysical, completely, torpedo, presses, luftwaffe,
# Nearest to it: less, discredited, past, timings, alternated, speculators, carnivorous, projecting,
# Nearest to seven: one, com, foes, marshal, saint, two, austrian, day,
# Nearest to as: rather, linguist, oscillator, congolese, prohibits, terminally, vocabularies, interprets,
# Nearest to institute: lipinski, conjugations, altdorfer, jul, dover, contessa, leaky, confidentially,
# Nearest to issue: larger, agent, diminish, ayahuasca, reagents, tsunamis, xxxii, hartree,
# Nearest to operating: professors, flair, network, wounding, af, surfing, spokesman, satellites,
# Nearest to active: seventy, oto, diagonal, antipsychotic, invade, mccartney, objected, formalist,
# Nearest to http: registrar, oaks, revisions, semester, roadmap, novas, seneca, agoraphobic,
# Nearest to creation: pomerania, yeltsin, orphic, ra, ruse, denunciation, wage, strenuously,
# Nearest to engineering: responding, dvg, gallop, earthquake, snapshot, curious, stretchy, centimeters,
# Nearest to additional: tomita, philologist, elite, inte, overstepped, standard, toy, reproduce,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6704 0.2899 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6883 0.2894 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6124 0.2875 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6145 0.3256 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6220 0.2929 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6239 0.2861 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6054 0.1944 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5431 0.2555 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5293 0.2625 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5147 0.3748 sec/batch
# Nearest to and: in, conquer, surgeries, diversification, protects, veal, reading, unusual,
# Nearest to nine: musician, one, six, w, jesuit, zero, songwriter, buckley,
# Nearest to all: horsemanship, ethyl, subdivision, subnet, auction, intercal, swelling, pilgrims,
# Nearest to has: discipline, sunk, geographically, angelika, pakistani, kops, conspiratorial, side,
# Nearest to is: berries, unphysical, byte, accumulation, completely, modula, torpedo, hoo,
# Nearest to it: less, carnivorous, past, discredited, timings, advantage, patches, speculators,
# Nearest to seven: one, marshal, two, nobel, austrian, jacques, j, b,
# Nearest to as: rather, oscillator, linguist, congolese, novels, terminally, technicians, prohibits,
# Nearest to institute: lipinski, conjugations, dover, altdorfer, school, jul, contessa, booked,
# Nearest to issue: larger, ayahuasca, agent, diminish, xxxii, yamamoto, legalize, colonialist,
# Nearest to operating: network, interfaces, professors, af, boehm, satellites, developers, flair,
# Nearest to active: seventy, oto, antipsychotic, diagonal, invade, mccartney, rest, romantically,
# Nearest to http: registrar, com, oaks, revisions, agoraphobic, semester, novas, roadmap,
# Nearest to creation: yeltsin, orphic, pomerania, ruse, ra, strenuously, emilio, denunciation,
# Nearest to engineering: dvg, responding, snapshot, gallop, amount, stretchy, earthquake, masquerade,
# Nearest to additional: tomita, standard, elite, reproduce, overstepped, toy, philologist, inte,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4907 0.2924 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4794 0.3162 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4559 0.2887 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5234 0.2770 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4888 0.2926 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4661 0.2830 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4390 0.2591 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3997 0.2808 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4249 0.2830 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4251 0.2585 sec/batch
# Nearest to and: in, protects, diversification, surgeries, conquer, djinni, veal, gaim,
# Nearest to nine: musician, pomeranian, newspapers, blackberry, zero, w, templo, founding,
# Nearest to all: horsemanship, subdivision, auction, ethyl, swelling, intercal, epistle, incongruity,
# Nearest to has: sunk, discipline, geographically, angelika, conspiratorial, kops, pakistani, eoin,
# Nearest to is: berries, unphysical, byte, accumulation, completely, reactions, slight, modula,
# Nearest to it: carnivorous, timings, discredited, less, past, projecting, patches, advantage,
# Nearest to seven: one, two, zero, marshal, com, j, costa, nobel,
# Nearest to as: rather, terminally, technicians, vocabularies, agree, oscillator, novels, prohibits,
# Nearest to institute: lipinski, altdorfer, school, conjugations, dover, jul, kent, contessa,
# Nearest to issue: ayahuasca, larger, diminish, angering, patriotic, agent, interfering, yamamoto,
# Nearest to operating: interfaces, network, developers, interface, compatible, professors, satellites, replacement,
# Nearest to active: antipsychotic, oto, seventy, invade, diagonal, trinomial, rest, objected,
# Nearest to http: com, web, registrar, www, revisions, agoraphobic, novas, roadmap,
# Nearest to creation: orphic, yeltsin, denunciation, ruse, pomerania, uninterrupted, ra, strenuously,
# Nearest to engineering: dvg, responding, centimeters, amount, imploded, communications, stretchy, astrobiology,
# Nearest to additional: standard, tomita, reproduce, overstepped, toy, inte, frequently, elite,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4246 0.2483 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4335 0.2408 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4204 0.2886 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3823 0.3493 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4095 0.3021 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4216 0.2912 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3811 0.3075 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3826 0.3211 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4091 0.4269 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3973 0.3744 sec/batch
# Nearest to and: in, surgeries, protects, djinni, hauser, are, muddy, conquer,
# Nearest to nine: musician, newspapers, founding, keitai, zero, saunders, pomeranian, kinney,
# Nearest to all: horsemanship, subdivision, ethyl, kilgore, warn, allure, incongruity, blatantly,
# Nearest to has: discipline, sunk, geographically, angelika, kops, pakistani, conspiratorial, side,
# Nearest to is: berries, unphysical, completely, accumulation, byte, modula, straddled, hoo,
# Nearest to it: timings, discredited, carnivorous, less, projecting, psychopathology, past, patches,
# Nearest to seven: two, one, zero, j, nobel, marshal, jurist, maul,
# Nearest to as: rather, terminally, vocabularies, technicians, congolese, agree, substituted, prohibits,
# Nearest to institute: lipinski, school, dover, altdorfer, conjugations, jul, academic, kent,
# Nearest to issue: ayahuasca, angering, diminish, larger, agent, pasting, legalize, patriotic,
# Nearest to operating: interfaces, developers, network, interface, proprietary, compatible, implementation, client,
# Nearest to active: antipsychotic, oto, objected, seventy, rest, invade, trinomial, diagonal,
# Nearest to http: com, web, www, edu, registrar, agoraphobic, novas, revisions,
# Nearest to creation: orphic, denunciation, yeltsin, uninterrupted, ruse, ra, capablanca, strenuously,
# Nearest to engineering: dvg, responding, imploded, stretchy, communications, astrobiology, computers, snapshot,
# Nearest to additional: standard, tomita, reproduce, overstepped, epona, toy, elite, inte,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3590 0.3345 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3618 0.2696 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3477 0.3035 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3622 0.3344 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3848 0.3073 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3814 0.2907 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4189 0.3426 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3852 0.2437 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3385 0.2539 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3179 0.2781 sec/batch
# Nearest to and: in, surgeries, are, djinni, protects, abgar, conquer, hauser,
# Nearest to nine: zero, newspapers, founding, kinney, templo, blackberry, keitai, three,
# Nearest to all: ethyl, horsemanship, intercal, allure, baire, subdivision, kilgore, regularity,
# Nearest to has: discipline, sunk, angelika, geographically, kops, maintains, routes, conspiratorial,
# Nearest to is: unphysical, berries, byte, completely, invertible, accumulation, borel, modula,
# Nearest to it: timings, discredited, carnivorous, less, projecting, alternated, patches, advantage,
# Nearest to seven: two, one, zero, three, five, four, j, birth,
# Nearest to as: rather, vocabularies, terminally, prohibits, congolese, interprets, technicians, novels,
# Nearest to institute: school, lipinski, altdorfer, dover, academic, conjugations, jul, taught,
# Nearest to issue: ayahuasca, diminish, pasting, legalize, patriotic, presidium, yamamoto, larger,
# Nearest to operating: network, interfaces, developers, interface, proprietary, client, compatible, implementation,
# Nearest to active: antipsychotic, oto, objected, denizens, trinomial, invade, seventy, rest,
# Nearest to http: web, com, www, edu, registrar, novas, revisions, dictionary,
# Nearest to creation: orphic, denunciation, uninterrupted, yeltsin, capablanca, ra, ruse, strenuously,
# Nearest to engineering: dvg, imploded, responding, stretchy, communications, astrobiology, wallpaper, tokens,
# Nearest to additional: standard, toy, overstepped, epona, reproduce, tomita, airs, opportune,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3314 0.3225 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3158 0.2886 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3551 0.2952 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3791 0.2954 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3907 0.2870 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2758 0.3110 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2827 0.2967 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3432 0.3333 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2098 0.3255 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2989 0.2948 sec/batch
# Nearest to and: in, surgeries, djinni, are, yangtze, hauser, amal, abgar,
# Nearest to nine: zero, one, four, two, newspapers, three, cullen, musician,
# Nearest to all: subdivision, ethyl, baire, horsemanship, regularity, kilgore, functional, intercal,
# Nearest to has: discipline, sunk, geographically, angelika, maintains, routes, octavius, kops,
# Nearest to is: berries, unphysical, invertible, modula, completely, lie, byte, accumulation,
# Nearest to it: timings, carnivorous, projecting, roulette, discredited, alternated, amorphous, less,
# Nearest to seven: two, one, zero, four, three, five, eight, marshal,
# Nearest to as: rather, vocabularies, terminally, prohibits, technicians, novels, with, congolese,
# Nearest to institute: school, lipinski, academic, dover, altdorfer, taught, graduate, conjugations,
# Nearest to issue: ayahuasca, diminish, pasting, patriotic, yamamoto, xxxii, angering, legalize,
# Nearest to operating: network, interfaces, developers, interface, proprietary, client, implementation, af,
# Nearest to active: antipsychotic, oto, objected, denizens, proleptic, seventy, envelop, rest,
# Nearest to http: web, com, www, edu, registrar, org, https, revisions,
# Nearest to creation: orphic, denunciation, uninterrupted, ruse, yeltsin, capablanca, strenuously, harmonizing,
# Nearest to engineering: dvg, imploded, communications, stretchy, responding, astrobiology, nitrate, unsanitary,
# Nearest to additional: tomita, overstepped, standard, epona, toy, reproduce, opportune, rutskoy,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3172 0.2793 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2879 0.3127 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3447 0.1224 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2292 0.2836 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2199 0.2995 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2133 0.2898 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2197 0.2814 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1818 0.2575 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2199 0.2668 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1633 0.2710 sec/batch
# Nearest to and: in, yangtze, are, djinni, surgeries, protects, seacoast, diversification,
# Nearest to nine: zero, two, four, three, newspapers, cullen, kinney, one,
# Nearest to all: subdivision, regularity, baire, intercal, horsemanship, borate, dme, incongruity,
# Nearest to has: sunk, discipline, geographically, angelika, asian, kops, routes, maintains,
# Nearest to is: unphysical, berries, completely, hoo, invertible, modula, myriads, every,
# Nearest to it: timings, carnivorous, projecting, roulette, quantifiers, less, amorphous, sado,
# Nearest to seven: two, one, zero, three, four, five, marshal, eight,
# Nearest to as: rather, vocabularies, technicians, terminally, with, congolese, novels, meir,
# Nearest to institute: school, academic, lipinski, dover, altdorfer, taught, graduate, columbia,
# Nearest to issue: ayahuasca, pasting, yamamoto, patriotic, angering, xxxii, diminish, legalize,
# Nearest to operating: network, interfaces, developers, proprietary, interface, client, replacement, macs,
# Nearest to active: antipsychotic, oto, invade, denizens, hyperlinks, trinomial, emedicine, envelop,
# Nearest to http: com, web, www, edu, https, org, html, registrar,
# Nearest to creation: orphic, denunciation, uninterrupted, ruse, otago, capablanca, yeltsin, harmonizing,
# Nearest to engineering: dvg, imploded, stretchy, responding, unsanitary, tech, astrobiology, amount,
# Nearest to additional: overstepped, epona, standard, tomita, toy, opportune, reproduce, rutskoy,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2266 0.2905 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2419 0.2766 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2191 0.2472 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1530 0.3279 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1496 0.2856 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1523 0.2728 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1688 0.2683 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1589 0.2904 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2155 0.2822 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1528 0.3166 sec/batch
# Nearest to and: in, are, djinni, yangtze, surgeries, protects, diversification, seacoast,
# Nearest to nine: zero, two, five, three, cullen, four, newspapers, kinney,
# Nearest to all: regularity, baire, horsemanship, subdivision, kilgore, epistle, countably, dme,
# Nearest to has: sunk, discipline, angelika, geographically, maintains, kops, octavius, geyser,
# Nearest to is: unphysical, berries, invertible, every, a, completely, generalize, myriads,
# Nearest to it: timings, carnivorous, projecting, calendars, discredited, patches, sado, roulette,
# Nearest to seven: two, zero, one, three, five, four, eight, jamil,
# Nearest to as: rather, vocabularies, with, terminally, technicians, oscillator, legendre, novels,
# Nearest to institute: school, academic, lipinski, dover, graduate, columbia, taught, altdorfer,
# Nearest to issue: ayahuasca, angering, pasting, patriotic, yamamoto, larger, interfering, mobilization,
# Nearest to operating: network, interfaces, developers, interface, client, proprietary, macs, af,
# Nearest to active: antipsychotic, oto, denizens, emedicine, envelop, invade, rest, hyperlinks,
# Nearest to http: www, com, web, edu, https, html, org, htm,
# Nearest to creation: orphic, uninterrupted, denunciation, writings, strenuously, ruse, capablanca, polyandry,
# Nearest to engineering: imploded, dvg, stretchy, tech, responding, stamps, astrobiology, boasts,
# Nearest to additional: overstepped, tomita, epona, reproduce, toy, standard, flare, illuminating,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.2133 0.2776 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2263 0.2768 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1880 0.2651 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1503 0.2940 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1750 0.2877 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2018 0.3012 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1927 0.3072 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1689 0.2770 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1409 0.2506 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1840 0.2189 sec/batch
# Nearest to and: in, blackstone, are, zonker, hauser, dymaxion, surgeries, djinni,
# Nearest to nine: zero, two, three, five, four, one, kinney, eight,
# Nearest to all: regularity, baire, kilgore, dme, countably, borate, colditz, horsemanship,
# Nearest to has: discipline, sunk, geographically, angelika, maintains, octavius, geyser, pakistani,
# Nearest to is: unphysical, berries, invertible, every, completely, a, curves, assemblers,
# Nearest to it: timings, carnivorous, projecting, calendars, discredited, alternated, asenath, sado,
# Nearest to seven: two, one, zero, three, five, four, eight, jamil,
# Nearest to as: rather, vocabularies, technicians, interprets, group, legendre, terminally, novels,
# Nearest to institute: school, academic, lipinski, dover, graduate, taught, educational, columbia,
# Nearest to issue: ayahuasca, angering, pasting, mobilization, agent, legalize, sepp, furlong,
# Nearest to operating: network, interfaces, developers, macs, af, proprietary, turbofan, client,
# Nearest to active: oto, denizens, antipsychotic, emedicine, invade, envelop, objected, rest,
# Nearest to http: www, com, web, edu, https, html, gov, htm,
# Nearest to creation: orphic, denunciation, uninterrupted, strenuously, ruse, harmonizing, writings, capablanca,
# Nearest to engineering: dvg, imploded, stretchy, tech, stamps, doodles, responding, astrobiology,
# Nearest to additional: tomita, epona, overstepped, reproduce, toy, flare, illuminating, opportune,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1890 0.2113 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1492 0.2408 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1960 0.2529 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1897 0.2776 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1401 0.2784 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1589 0.2806 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1911 0.2854 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1568 0.2812 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1874 0.2605 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2187 0.2570 sec/batch
# Nearest to and: in, elector, blackstone, hauser, amal, dunfermline, zonker, unitarians,
# Nearest to nine: zero, one, two, three, four, five, six, eight,
# Nearest to all: regularity, kilgore, colditz, baire, subdivision, dme, intercal, countably,
# Nearest to has: discipline, angelika, sunk, octavius, maintains, geographically, geyser, roughly,
# Nearest to is: unphysical, berries, hoo, every, strongpoints, invertible, imbolc, sina,
# Nearest to it: timings, projecting, alternated, carnivorous, calendars, discredited, asenath, sado,
# Nearest to seven: two, one, three, zero, four, five, eight, six,
# Nearest to as: rather, vocabularies, thynne, meir, novels, congolese, with, interprets,
# Nearest to institute: school, academic, dover, lipinski, columbia, taught, graduate, educational,
# Nearest to issue: ayahuasca, sepp, yamamoto, legalize, mobilization, furlong, pasting, angering,
# Nearest to operating: network, interfaces, af, developers, asterix, macs, proprietary, turbofan,
# Nearest to active: antipsychotic, denizens, oto, emedicine, objected, hyperlinks, invade, jubal,
# Nearest to http: www, com, web, edu, https, html, gov, htm,
# Nearest to creation: orphic, uninterrupted, denunciation, strenuously, harmonizing, ruse, otago, capablanca,
# Nearest to engineering: imploded, dvg, stretchy, undergraduate, tech, stamps, doodles, boasts,
# Nearest to additional: tomita, overstepped, epona, toy, airs, flare, rutskoy, reproduce,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2470 0.2880 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1699 0.2865 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1236 0.2756 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1486 0.2773 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0281 0.2798 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1480 0.2841 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1464 0.2905 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1344 0.3124 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1515 0.0381 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1427 0.2779 sec/batch
# Nearest to and: in, are, skyview, zonker, yangtze, introduced, dymaxion, baguirmi,
# Nearest to nine: zero, two, one, three, four, five, eight, six,
# Nearest to all: regularity, countably, baire, kilgore, colditz, dme, intercal, subdivision,
# Nearest to has: discipline, sunk, geographically, maintains, angelika, octavius, asian, roughly,
# Nearest to is: unphysical, berries, a, every, invertible, assemblers, lie, hoo,
# Nearest to it: timings, projecting, carnivorous, sado, amorphous, calendars, roulette, alternated,
# Nearest to seven: two, one, three, zero, four, five, eight, ppp,
# Nearest to as: rather, vocabularies, the, with, interprets, legendre, invariants, prohibits,
# Nearest to institute: school, columbia, academic, lipinski, taught, dover, educational, altdorfer,
# Nearest to issue: weather, yamamoto, legalize, ayahuasca, mobilization, pasting, diminish, sepp,
# Nearest to operating: interfaces, macs, developers, binaries, network, client, af, proprietary,
# Nearest to active: denizens, oto, antipsychotic, emedicine, hyperlinks, objected, rest, envelop,
# Nearest to http: www, com, web, edu, https, html, htm, gov,
# Nearest to creation: orphic, denunciation, uninterrupted, strenuously, harmonizing, ruse, capablanca, validate,
# Nearest to engineering: imploded, dvg, stretchy, tech, undergraduate, stamps, doodles, boasts,
# Nearest to additional: flare, tomita, overstepped, toy, reproduce, epona, standard, rutskoy,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0668 0.2798 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0738 0.2888 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0791 0.2147 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0826 0.2132 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0841 0.2077 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0456 0.2075 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0900 0.2099 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0797 0.2070 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1185 0.2122 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0585 0.2140 sec/batch
# Nearest to and: in, are, zonker, skyview, yangtze, introduced, komondor, dymaxion,
# Nearest to nine: zero, two, three, one, five, four, kinney, founding,
# Nearest to all: regularity, countably, baire, subdivision, colditz, dme, quad, kilgore,
# Nearest to has: discipline, octavius, sunk, geographically, seperatist, angelika, maintains, asian,
# Nearest to is: unphysical, a, berries, every, invertible, there, strongpoints, lie,
# Nearest to it: timings, projecting, carnivorous, sado, come, damadian, patches, calendars,
# Nearest to seven: two, zero, three, one, five, four, eight, ppp,
# Nearest to as: rather, with, the, vocabularies, of, such, technicians, toned,
# Nearest to institute: school, academic, taught, lipinski, columbia, dover, educational, altdorfer,
# Nearest to issue: weather, ayahuasca, mobilization, yamamoto, legalize, diminish, pasting, sepp,
# Nearest to operating: interfaces, macs, binaries, developers, proprietary, network, client, perl,
# Nearest to active: antipsychotic, oto, denizens, emedicine, hyperlinks, invade, rest, gsm,
# Nearest to http: www, com, web, edu, https, html, htm, org,
# Nearest to creation: orphic, denunciation, harmonizing, uninterrupted, validate, strenuously, ruse, otago,
# Nearest to engineering: imploded, stretchy, tech, undergraduate, dvg, stamps, doodles, responding,
# Nearest to additional: tomita, overstepped, toy, epona, airs, reproduce, flare, standard,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0332 0.2079 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0406 0.2079 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0328 0.2063 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0734 0.2154 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0675 0.2081 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0835 0.2088 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0342 0.2082 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1115 0.2070 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0628 0.2069 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0019 0.2065 sec/batch
# Nearest to and: in, are, introduced, bsl, eugenicists, zonker, the, skyview,
# Nearest to nine: zero, two, three, one, five, four, eight, six,
# Nearest to all: regularity, countably, colditz, quad, kilgore, baire, subdivision, intercal,
# Nearest to has: discipline, angelika, sunk, octavius, contexts, roughly, geyser, maintains,
# Nearest to is: a, unphysical, berries, every, invertible, that, there, endomorphisms,
# Nearest to it: timings, projecting, sado, carnivorous, come, kaposi, functionalities, gorillaz,
# Nearest to seven: two, three, zero, one, four, five, eight, six,
# Nearest to as: rather, vocabularies, with, the, such, of, legendre, group,
# Nearest to institute: school, columbia, lipinski, taught, academic, dover, altdorfer, educational,
# Nearest to issue: weather, ayahuasca, mobilization, legalize, pasting, larger, sepp, yamamoto,
# Nearest to operating: interfaces, macs, developers, binaries, proprietary, network, intel, perl,
# Nearest to active: denizens, antipsychotic, emedicine, hyperlinks, oto, invade, rest, geophysical,
# Nearest to http: www, com, edu, web, https, html, htm, org,
# Nearest to creation: orphic, denunciation, uninterrupted, ruse, harmonizing, underlies, strenuously, validate,
# Nearest to engineering: imploded, stretchy, undergraduate, dvg, tech, modeling, stamps, doodles,
# Nearest to additional: overstepped, standard, reproduce, tomita, flare, toy, airs, empathic,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0826 0.2086 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0975 0.2082 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0688 0.2081 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0728 0.2088 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0903 0.2078 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0508 0.2067 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0712 0.2085 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0678 0.2064 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0945 0.2077 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0693 0.2077 sec/batch
# Nearest to and: in, the, swami, eugenicists, are, introduced, elector, yangtze,
# Nearest to nine: zero, two, three, one, five, four, eight, six,
# Nearest to all: regularity, countably, colditz, quad, kilgore, intercal, dme, baire,
# Nearest to has: discipline, octavius, angelika, sunk, roughly, seperatist, valley, geyser,
# Nearest to is: unphysical, every, berries, a, invertible, there, lie, strongpoints,
# Nearest to it: timings, projecting, carnivorous, sado, asenath, amorphous, alternated, kaposi,
# Nearest to seven: two, one, three, zero, four, five, eight, six,
# Nearest to as: rather, with, the, vocabularies, of, such, thynne, interprets,
# Nearest to institute: school, columbia, lipinski, taught, academic, dover, altdorfer, bootp,
# Nearest to issue: weather, mobilization, sepp, ayahuasca, legalize, larger, pasting, breckenridge,
# Nearest to operating: interfaces, macs, developers, binaries, proprietary, perl, program, dos,
# Nearest to active: denizens, hyperlinks, antipsychotic, emedicine, invade, oto, objected, demilitarisation,
# Nearest to http: www, com, edu, web, https, html, htm, gov,
# Nearest to creation: orphic, denunciation, harmonizing, uninterrupted, ruse, validate, strenuously, otago,
# Nearest to engineering: imploded, dvg, stretchy, undergraduate, tech, stamps, doodles, modeling,
# Nearest to additional: overstepped, tomita, reproduce, toy, opportune, epona, flare, illuminating,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0375 0.2082 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0067 0.2102 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0146 0.2094 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.1033 0.2081 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0545 0.2085 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1280 0.2076 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1553 0.2076 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0570 0.2076 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0383 0.2131 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0602 0.2073 sec/batch
# Nearest to and: in, are, eugenicists, komondor, skyview, the, bsl, dymaxion,
# Nearest to nine: zero, two, three, one, four, five, eight, six,
# Nearest to all: regularity, countably, intercal, colditz, quad, baire, kilgore, anyway,
# Nearest to has: discipline, valley, octavius, angelika, roughly, seperatist, geyser, geographically,
# Nearest to is: a, berries, unphysical, every, lie, invertible, endomorphisms, there,
# Nearest to it: timings, projecting, sado, carnivorous, come, alternated, amorphous, sarde,
# Nearest to seven: two, three, one, zero, four, five, eight, six,
# Nearest to as: rather, the, with, vocabularies, of, such, toned, by,
# Nearest to institute: school, taught, columbia, lipinski, academic, sciences, altdorfer, dover,
# Nearest to issue: weather, mobilization, sepp, ayahuasca, pasting, larger, yamamoto, legalize,
# Nearest to operating: interfaces, macs, developers, proprietary, binaries, intel, asterix, perl,
# Nearest to active: denizens, hyperlinks, antipsychotic, emedicine, invade, oto, rest, modernisation,
# Nearest to http: www, com, edu, https, web, html, org, htm,
# Nearest to creation: orphic, denunciation, ruse, harmonizing, uninterrupted, validate, otago, capablanca,
# Nearest to engineering: imploded, stretchy, tech, undergraduate, dvg, doodles, stamps, sciences,
# Nearest to additional: tomita, overstepped, reproduce, toy, flare, epona, illuminating, filipinos,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9819 0.2070 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0140 0.2074 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0271 0.2068 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0144 0.2066 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0808 0.2096 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0358 0.1735 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0143 0.2103 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9864 0.2067 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0186 0.2065 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9506 0.2089 sec/batch
# Nearest to and: in, are, the, yangtze, of, zonker, skyview, swami,
# Nearest to nine: zero, two, one, three, four, five, eight, six,
# Nearest to all: regularity, intercal, countably, quad, kilgore, wat, anyway, several,
# Nearest to has: roughly, discipline, valley, asian, seperatist, angelika, octavius, contexts,
# Nearest to is: berries, a, unphysical, every, there, invertible, hoo, lie,
# Nearest to it: timings, projecting, sado, carnivorous, come, amorphous, quantifiers, sarde,
# Nearest to seven: one, two, three, zero, five, four, eight, six,
# Nearest to as: rather, with, such, the, vocabularies, of, by, toned,
# Nearest to institute: school, taught, columbia, lipinski, academic, educational, sciences, altdorfer,
# Nearest to issue: weather, sepp, mobilization, larger, pasting, breckenridge, ayahuasca, blunder,
# Nearest to operating: macs, interfaces, binaries, proprietary, intel, developers, asterix, loader,
# Nearest to active: denizens, hyperlinks, invade, rest, antipsychotic, emedicine, oto, implications,
# Nearest to http: www, com, edu, https, web, org, htm, gov,
# Nearest to creation: orphic, denunciation, ruse, validate, harmonizing, capablanca, uninterrupted, otago,
# Nearest to engineering: imploded, tech, undergraduate, stretchy, dvg, modeling, substitute, sciences,
# Nearest to additional: tomita, overstepped, toy, flare, filipinos, opportune, epona, rutskoy,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0233 0.2077 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9443 0.2145 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0045 0.2139 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0077 0.2084 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0211 0.2092 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9886 0.2103 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9228 0.2087 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9615 0.2085 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9551 0.2098 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9852 0.2086 sec/batch
# Nearest to and: in, are, the, of, yangtze, introduced, zonker, diversification,
# Nearest to nine: two, zero, three, one, five, four, eight, six,
# Nearest to all: regularity, countably, quad, intercal, baire, kilgore, anyway, borate,
# Nearest to has: discipline, roughly, seperatist, trygve, valley, trust, angelika, octavius,
# Nearest to is: a, berries, every, there, unphysical, invertible, lie, that,
# Nearest to it: timings, projecting, sado, carnivorous, come, sarde, speculators, armenian,
# Nearest to seven: two, three, one, zero, five, four, eight, six,
# Nearest to as: rather, with, such, the, vocabularies, of, toned, a,
# Nearest to institute: school, columbia, lipinski, morehouse, taught, educational, academic, altdorfer,
# Nearest to issue: weather, larger, mobilization, sepp, adr, pasting, disenfranchised, breckenridge,
# Nearest to operating: macs, interfaces, proprietary, binaries, program, intel, dos, loader,
# Nearest to active: denizens, hyperlinks, antipsychotic, invade, rest, emedicine, geophysical, demilitarisation,
# Nearest to http: www, com, edu, https, web, org, htm, html,
# Nearest to creation: orphic, denunciation, harmonizing, capablanca, uninterrupted, validate, ruse, strenuously,
# Nearest to engineering: undergraduate, imploded, tech, stretchy, computer, dvg, substitute, sciences,
# Nearest to additional: tomita, overstepped, toy, filipinos, flare, reproduce, opportune, willis,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9867 0.2094 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9960 0.2119 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9668 0.2086 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0126 0.2091 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0291 0.2089 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9364 0.2082 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0113 0.2095 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9912 0.2158 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0008 0.2079 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0029 0.2080 sec/batch
# Nearest to and: in, the, of, are, introduced, zonker, eugenicists, for,
# Nearest to nine: two, one, zero, three, four, five, eight, six,
# Nearest to all: regularity, quad, countably, kilgore, colditz, baire, intercal, several,
# Nearest to has: roughly, discipline, trust, valley, seperatist, angelika, octavius, contexts,
# Nearest to is: a, every, that, berries, there, invertible, unphysical, hoo,
# Nearest to it: projecting, timings, sado, come, carnivorous, sarde, why, speculators,
# Nearest to seven: two, one, three, zero, four, five, eight, six,
# Nearest to as: with, rather, the, of, such, a, vocabularies, toned,
# Nearest to institute: school, columbia, lipinski, taught, altdorfer, morehouse, educational, iowa,
# Nearest to issue: weather, larger, sepp, adr, mobilization, breckenridge, pasting, disenfranchised,
# Nearest to operating: macs, proprietary, binaries, dos, intel, interfaces, loader, asterix,
# Nearest to active: denizens, hyperlinks, rest, invade, emedicine, antipsychotic, demilitarisation, modernisation,
# Nearest to http: www, com, edu, https, web, html, org, htm,
# Nearest to creation: orphic, denunciation, ruse, capablanca, harmonizing, uninterrupted, validate, otago,
# Nearest to engineering: undergraduate, stretchy, computer, imploded, substitute, tech, dvg, modeling,
# Nearest to additional: overstepped, toy, flare, tomita, filipinos, standard, illuminating, rutskoy,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9952 0.2087 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9852 0.2091 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9822 0.2107 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0181 0.2081 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0132 0.2088 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9990 0.2104 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9945 0.2092 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9534 0.2096 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9854 0.2106 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0257 0.2109 sec/batch
# Nearest to and: in, the, of, are, for, zonker, introduced, as,
# Nearest to nine: two, zero, one, three, four, five, eight, six,
# Nearest to all: regularity, quad, countably, intercal, several, illyricum, listing, baire,
# Nearest to has: roughly, discipline, trust, valley, contexts, isi, angelika, seperatist,
# Nearest to is: a, every, there, that, berries, strongpoints, exists, hoo,
# Nearest to it: timings, come, projecting, speculators, sado, sarde, carnivorous, functionalities,
# Nearest to seven: two, three, one, four, zero, eight, five, six,
# Nearest to as: of, the, with, such, rather, a, by, in,
# Nearest to institute: school, columbia, lipinski, taught, altdorfer, morehouse, academic, educational,
# Nearest to issue: weather, larger, sepp, adr, disenfranchised, pasting, blunder, issues,
# Nearest to operating: macs, proprietary, binaries, loader, dos, interfaces, intel, asterix,
# Nearest to active: denizens, antipsychotic, invade, hyperlinks, rest, demilitarisation, emedicine, modernisation,
# Nearest to http: www, com, edu, https, web, html, htm, org,
# Nearest to creation: orphic, denunciation, ruse, validate, capablanca, harmonizing, overstepped, otago,
# Nearest to engineering: substitute, undergraduate, stretchy, imploded, computer, boasts, doodles, dvg,
# Nearest to additional: overstepped, toy, filipinos, standard, illuminating, willis, flare, opportune,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9610 0.2084 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0919 0.2135 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0547 0.2086 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0609 0.2081 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9615 0.2115 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9271 0.2082 sec/batch
# ...
# Nearest to http: www, edu, htm, com, https, web, html, gov,
# Nearest to creation: capablanca, martha, cocoa, validate, overstepped, revealed, ns, denunciation,
# Nearest to engineering: substitute, computer, timescale, hadrons, subfields, undergraduate, beal, stretchy,
# Nearest to additional: sacra, filipinos, faxes, willis, aisles, illuminating, legitimize, windu,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.8784 0.2141 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7421 0.2144 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8388 0.2161 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7962 0.2170 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.7941 0.2149 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8621 0.2144 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8629 0.2136 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8438 0.2134 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8726 0.2157 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9041 0.2133 sec/batch
# Nearest to and: the, in, for, a, of, with, as, are,
# Nearest to nine: one, three, four, eight, two, zero, six, five,
# Nearest to all: several, any, so, the, regularity, listing, be, quad,
# Nearest to has: been, is, in, as, both, a, and, valley,
# Nearest to is: a, as, in, of, that, the, are, has,
# Nearest to it: as, that, is, only, timings, the, be, to,
# Nearest to seven: one, three, four, eight, six, two, five, zero,
# Nearest to as: a, the, such, of, in, is, with, and,
# Nearest to institute: fordham, morehouse, columbia, research, altdorfer, school, osnabr, bootp,
# Nearest to issue: blunder, weather, larger, flurry, obvious, inelegant, disenfranchised, negating,
# Nearest to operating: macs, program, systems, loader, unix, running, riser, modernist,
# Nearest to active: denizens, rest, geophysical, hyperlinks, kinetics, demilitarisation, hydroxy, hither,
# Nearest to http: www, edu, htm, com, https, web, html, org,
# Nearest to creation: martha, overstepped, capablanca, cocoa, revealed, validate, orphic, chargaff,
# Nearest to engineering: substitute, computer, timescale, subfields, hadrons, undergraduate, beal, quintilian,
# Nearest to additional: sacra, faxes, filipinos, illuminating, willis, aisles, standard, cricketing,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8666 0.2186 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8477 0.2137 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8502 0.2135 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8438 0.2151 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8718 0.2124 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8877 0.2136 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8531 0.2136 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8568 0.2130 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8874 0.2167 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8628 0.2179 sec/batch
# Nearest to and: in, the, for, of, a, with, as, by,
# Nearest to nine: one, three, four, zero, two, eight, six, five,
# Nearest to all: several, any, so, listing, regularity, be, cardinality, the,
# Nearest to has: is, as, in, been, a, both, valley, point,
# Nearest to is: a, as, in, has, of, also, its, are,
# Nearest to it: that, is, only, as, timings, to, be, the,
# Nearest to seven: one, three, four, eight, six, five, two, zero,
# Nearest to as: a, the, of, such, in, with, is, and,
# Nearest to institute: fordham, morehouse, bootp, columbia, osnabr, research, altdorfer, benjamins,
# Nearest to issue: larger, blunder, weather, obvious, flurry, disenfranchised, negating, inelegant,
# Nearest to operating: macs, program, systems, unix, proprietary, loader, riser, modernist,
# Nearest to active: denizens, rest, kinetics, hyperlinks, geophysical, hydroxy, hither, demilitarisation,
# Nearest to http: www, edu, htm, https, com, html, web, org,
# Nearest to creation: martha, capablanca, overstepped, cocoa, orphic, validate, revealed, garnett,
# Nearest to engineering: substitute, timescale, computer, subfields, hadrons, dvg, quintilian, stretchy,
# Nearest to additional: sacra, faxes, willis, illuminating, filipinos, aisles, legitimize, cricketing,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8848 0.2144 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8503 0.2140 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8498 0.2148 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8665 0.2133 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8649 0.2205 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8321 0.2196 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9332 0.2150 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8932 0.2136 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8836 0.2140 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8163 0.2142 sec/batch
# Nearest to and: the, in, for, of, as, with, a, by,
# Nearest to nine: one, four, three, two, eight, zero, six, five,
# Nearest to all: several, any, regularity, listing, so, and, anyway, two,
# Nearest to has: is, as, been, in, valley, the, and, both,
# Nearest to is: a, as, of, in, the, has, it, its,
# Nearest to it: that, is, as, the, to, be, only, an,
# Nearest to seven: four, one, three, six, eight, five, two, zero,
# Nearest to as: the, of, a, in, such, and, with, is,
# Nearest to institute: fordham, morehouse, dissertation, altdorfer, columbia, osnabr, research, benjamins,
# Nearest to issue: blunder, negating, larger, weather, obvious, flurry, inelegant, issues,
# Nearest to operating: macs, unix, systems, program, proprietary, running, loader, riser,
# Nearest to active: denizens, rest, kinetics, hyperlinks, hither, hydroxy, geophysical, demilitarisation,
# Nearest to http: www, edu, htm, com, https, html, org, web,
# Nearest to creation: martha, cocoa, overstepped, capablanca, dmu, thrilled, validate, garnett,
# Nearest to engineering: substitute, computer, timescale, subfields, undergraduate, beal, hadrons, hennessy,
# Nearest to additional: sacra, faxes, filipinos, willis, aisles, illuminating, cricketing, ong,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8261 0.2176 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8608 0.2128 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7788 0.2145 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8611 0.2134 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8687 0.2136 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8459 0.2170 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9333 0.0830 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8171 0.2143 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8736 0.2203 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8189 0.2137 sec/batch
# Nearest to and: the, in, of, for, with, a, as, to,
# Nearest to nine: one, four, three, eight, two, six, zero, five,
# Nearest to all: several, any, so, regularity, other, be, metta, smote,
# Nearest to has: is, been, in, as, both, valley, roughly, a,
# Nearest to is: a, as, in, the, of, also, has, to,
# Nearest to it: that, the, is, as, only, to, be, an,
# Nearest to seven: one, four, six, three, five, eight, two, zero,
# Nearest to as: a, the, such, of, in, with, is, and,
# Nearest to institute: fordham, morehouse, dissertation, osnabr, altdorfer, lipinski, columbia, school,
# Nearest to issue: larger, blunder, negating, flurry, inelegant, weather, obvious, sepp,
# Nearest to operating: macs, unix, running, systems, program, proprietary, loader, modernist,
# Nearest to active: denizens, rest, hither, kinetics, hydroxy, geophysical, hyperlinks, demilitarisation,
# Nearest to http: www, edu, htm, com, https, html, org, web,
# Nearest to creation: martha, capablanca, overstepped, thrilled, cocoa, garnett, ns, aage,
# Nearest to engineering: substitute, timescale, computer, hennessy, subfields, quintilian, stretchy, hadrons,
# Nearest to additional: sacra, filipinos, faxes, aisles, illuminating, willis, ong, legitimize,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8476 0.2159 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8161 0.2146 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8406 0.2134 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7889 0.2128 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8480 0.2134 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8256 0.2137 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8863 0.2140 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7592 0.2162 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8019 0.2141 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8288 0.2151 sec/batch
# Nearest to and: the, for, in, with, of, a, as, are,
# Nearest to nine: one, three, four, two, eight, zero, six, five,
# Nearest to all: any, several, so, be, the, other, to, listing,
# Nearest to has: been, is, in, as, the, a, both, and,
# Nearest to is: a, as, the, in, of, that, for, to,
# Nearest to it: is, as, that, only, the, to, timings, an,
# Nearest to seven: one, three, four, six, five, eight, two, zero,
# Nearest to as: the, a, of, such, in, which, with, is,
# Nearest to institute: fordham, morehouse, dissertation, buildings, osnabr, lipinski, columbia, altdorfer,
# Nearest to issue: larger, negating, weather, blunder, obvious, flurry, inelegant, noting,
# Nearest to operating: macs, unix, program, systems, running, loader, proprietary, cans,
# Nearest to active: denizens, rest, geophysical, kinetics, hyperlinks, hydroxy, hither, eez,
# Nearest to http: www, edu, htm, com, https, html, org, web,
# Nearest to creation: overstepped, martha, cocoa, capablanca, ns, sykes, validate, revealed,
# Nearest to engineering: substitute, computer, timescale, subfields, specialized, undergraduate, stretchy, hennessy,
# Nearest to additional: filipinos, sacra, faxes, willis, aisles, rutskoy, illuminating, ong,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7111 0.2142 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8156 0.2140 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8538 0.2184 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8248 0.2157 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8363 0.2140 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9049 0.2137 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8654 0.2137 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8136 0.2136 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8405 0.2154 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8209 0.2130 sec/batch
# Nearest to and: in, for, the, of, with, a, as, are,
# Nearest to nine: one, three, four, eight, two, zero, six, five,
# Nearest to all: several, any, so, the, listing, regularity, to, and,
# Nearest to has: been, in, as, is, the, a, both, and,
# Nearest to is: a, as, in, the, of, that, to, has,
# Nearest to it: that, as, is, only, the, to, an, be,
# Nearest to seven: one, four, three, six, eight, five, two, zero,
# Nearest to as: a, the, of, such, in, with, is, which,
# Nearest to institute: fordham, morehouse, columbia, osnabr, buildings, dissertation, altdorfer, lipinski,
# Nearest to issue: larger, flurry, blunder, negating, inelegant, obvious, weather, disenfranchised,
# Nearest to operating: macs, program, running, unix, systems, loader, cans, defections,
# Nearest to active: denizens, rest, hither, geophysical, hyperlinks, kinetics, hydroxy, eez,
# Nearest to http: www, edu, htm, com, https, html, org, web,
# Nearest to creation: overstepped, martha, revealed, cocoa, thrilled, capablanca, garnett, rathbone,
# Nearest to engineering: substitute, computer, timescale, stretchy, hennessy, undergraduate, specialized, subfields,
# Nearest to additional: sacra, faxes, filipinos, aisles, willis, ong, cricketing, illuminating,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8766 0.2204 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8172 0.2126 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8245 0.2133 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8701 0.2153 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8096 0.2117 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8517 0.2130 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8253 0.2181 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8349 0.2201 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8107 0.2130 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8381 0.2172 sec/batch
# Nearest to and: in, for, the, of, as, with, a, to,
# Nearest to nine: one, three, four, eight, two, zero, six, five,
# Nearest to all: several, any, be, the, to, and, other, so,
# Nearest to has: been, is, as, in, a, the, both, which,
# Nearest to is: a, as, in, the, it, of, also, has,
# Nearest to it: is, as, the, that, only, be, to, an,
# Nearest to seven: four, three, one, six, eight, five, two, zero,
# Nearest to as: the, a, of, such, in, with, is, which,
# Nearest to institute: fordham, morehouse, columbia, osnabr, research, dissertation, buildings, altdorfer,
# Nearest to issue: larger, blunder, flurry, negating, issues, obvious, inelegant, disenfranchised,
# Nearest to operating: macs, systems, unix, program, running, loader, proprietary, defections,
# Nearest to active: denizens, rest, hither, kinetics, hyperlinks, geophysical, hydroxy, eez,
# Nearest to http: www, htm, edu, com, https, html, org, gov,
# Nearest to creation: overstepped, revealed, martha, thrilled, sykes, cocoa, dmu, aage,
# Nearest to engineering: substitute, timescale, stretchy, computer, undergraduate, beal, subfields, hennessy,
# Nearest to additional: sacra, faxes, filipinos, aisles, cricketing, willis, illuminating, ong,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8262 0.2151 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8416 0.2146 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8676 0.2139 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9242 0.2130 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8931 0.2133 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8254 0.2151 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7955 0.2126 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8331 0.2130 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7206 0.2134 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8716 0.2136 sec/batch
# Nearest to and: the, for, in, of, a, with, as, are,
# Nearest to nine: one, four, three, two, eight, zero, six, five,
# Nearest to all: several, any, the, be, and, so, other, listing,
# Nearest to has: been, in, as, is, the, a, both, and,
# Nearest to is: a, in, as, the, has, of, it, also,
# Nearest to it: is, that, as, the, be, only, an, to,
# Nearest to seven: one, four, six, three, five, eight, two, zero,
# Nearest to as: the, a, such, of, with, in, which, and,
# Nearest to institute: fordham, morehouse, dissertation, osnabr, columbia, altdorfer, kumamoto, buildings,
# Nearest to issue: blunder, flurry, larger, inelegant, issues, negating, obvious, mobilization,
# Nearest to operating: unix, macs, systems, running, program, proprietary, roddick, loader,
# Nearest to active: rest, denizens, hither, kinetics, hydroxy, hyperlinks, initiatives, eez,
# Nearest to http: www, htm, edu, com, https, html, org, web,
# Nearest to creation: martha, thrilled, overstepped, cocoa, sykes, revealed, capablanca, aage,
# Nearest to engineering: substitute, stretchy, timescale, beal, computer, dvg, hadrons, undergraduate,
# Nearest to additional: filipinos, faxes, sacra, gabor, ong, aisles, radiocommunications, rutskoy,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8457 0.2201 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8407 0.2136 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
